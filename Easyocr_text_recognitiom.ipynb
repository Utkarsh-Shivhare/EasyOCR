# %%
# !pip install easyocr
# Out:
# Collecting easyocr
#   Using cached easyocr-1.6.2-py3-none-any.whl (2.9 MB)
# Requirement already satisfied: torchvision>=0.5 in c:\users\utkar\anaconda3\lib\site-packages (from easyocr) (0.15.1)
# Requirement already satisfied: scipy in c:\users\utkar\anaconda3\lib\site-packages (from easyocr) (1.10.1)
# Requirement already satisfied: torch in c:\users\utkar\anaconda3\lib\site-packages (from easyocr) (2.0.0)
# Requirement already satisfied: Pillow in c:\users\utkar\anaconda3\lib\site-packages (from easyocr) (9.2.0)
# Requirement already satisfied: opencv-python-headless<=4.5.4.60 in c:\users\utkar\anaconda3\lib\site-packages (from easyocr) (4.5.4.60)
# Requirement already satisfied: numpy in c:\users\utkar\anaconda3\lib\site-packages (from easyocr) (1.23.5)
# Requirement already satisfied: scikit-image in c:\users\utkar\anaconda3\lib\site-packages (from easyocr) (0.19.2)
# Requirement already satisfied: python-bidi in c:\users\utkar\anaconda3\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: PyYAML in c:\users\utkar\anaconda3\lib\site-packages (from easyocr) (5.4.1)
# Requirement already satisfied: Shapely in c:\users\utkar\anaconda3\lib\site-packages (from easyocr) (2.0.1)
# Requirement already satisfied: pyclipper in c:\users\utkar\anaconda3\lib\site-packages (from easyocr) (1.3.0.post4)
# Requirement already satisfied: ninja in c:\users\utkar\anaconda3\lib\site-packages (from easyocr) (1.11.1)
# Requirement already satisfied: requests in c:\users\utkar\anaconda3\lib\site-packages (from torchvision>=0.5->easyocr) (2.26.0)
# Requirement already satisfied: filelock in c:\users\utkar\anaconda3\lib\site-packages (from torch->easyocr) (3.0.12)
# Requirement already satisfied: networkx in c:\users\utkar\anaconda3\lib\site-packages (from torch->easyocr) (2.8.4)
# Requirement already satisfied: typing-extensions in c:\users\utkar\anaconda3\lib\site-packages (from torch->easyocr) (4.1.1)
# Requirement already satisfied: jinja2 in c:\users\utkar\anaconda3\lib\site-packages (from torch->easyocr) (3.0.3)
# Requirement already satisfied: sympy in c:\users\utkar\anaconda3\lib\site-packages (from torch->easyocr) (1.10.1)
# Requirement already satisfied: six in c:\users\utkar\anaconda3\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\utkar\anaconda3\lib\site-packages (from scikit-image->easyocr) (1.3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\utkar\anaconda3\lib\site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\utkar\anaconda3\lib\site-packages (from scikit-image->easyocr) (21.3)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\utkar\anaconda3\lib\site-packages (from scikit-image->easyocr) (2.19.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\utkar\anaconda3\lib\site-packages (from packaging>=20.0->scikit-image->easyocr) (2.4.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\utkar\anaconda3\lib\site-packages (from jinja2->torch->easyocr) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\utkar\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\utkar\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\utkar\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\utkar\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.7)
# Requirement already satisfied: mpmath>=0.19 in c:\users\utkar\anaconda3\lib\site-packages (from sympy->torch->easyocr) (1.2.1)
# Installing collected packages: easyocr
# Successfully installed easyocr-1.6.2

# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img_path="img.png"
reader=easyocr.Reader(['en'],gpu=True)
result=reader.readtext(img_path)
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[4, 6], [218, 6], [218, 36], [4, 36]],
#   'It was the best of',
#   0.7858967434866992),
#  ([[3, 40], [276, 40], [276, 70], [3, 70]],
#   'times, it was the worst',
#   0.7649300445572378),
#  ([[3, 73], [281, 73], [281, 109], [3, 109]],
#   'of times, it was the age',
#   0.9663759397569865),
#  ([[3, 103], [263, 103], [263, 139], [3, 139]],
#   'of wisdom; it was the',
#   0.8666285007927751),
#  ([[3, 137], [229, 137], [229, 175], [3, 175]],
#   'age of foolishness_',
#   0.959230537032981)]

# %%
top_left=tuple(result[0][0][0])
bottom_right=tuple(result[0][0][2])
text=result[0][1]
font=cv2.FONT_HERSHEY_SIMPLEX

# %%
img=cv2.imread(img_path)
img=cv2.rectangle(img,top_left,bottom_right,(0,255,0),5)
img=cv2.putText(img,text,top_left,font,.5,(255,255,255),1,cv2.LINE_AA)
plt.imshow(img)
plt.show()

# %%
img=cv2.imread(img_path)
for detection in result:
    top_left=tuple([int(val) for val in detection[0][0]])
    bottom_right=tuple([int(val) for val in detection[0][2]])
    text=detection[1]
    font=cv2.FONT_HERSHEY_SIMPLEX
    img=cv2.rectangle(img,top_left,bottom_right,(0,255,0),5)
    img=cv2.putText(img,text,top_left,font,.2,(255,255,255),1,cv2.LINE_AA)
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()

# %%
import cv2

cap = cv2.VideoCapture("1.mp4")

while True:
    success, img = cap.read()
    if not success:
        break
    if img.shape[0] == 0 or img.shape[1] == 0:
        continue
    cv2.imshow("image", img)
    cv2.waitKey(1)

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [22], in <cell line: 15>()
#      12     cv2.waitKey(1)
#      14 cap.release()
# ---> 15 cv2.destroyAllWindows()
#
# error: OpenCV(4.5.4) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1268: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'

# %%
cap.release()

# %%
conda remove opencv
conda update conda
conda install --channel menpo opencv
# Out:
#   Input In [23]
#     conda remove opencv
#           ^
# SyntaxError: invalid syntax
